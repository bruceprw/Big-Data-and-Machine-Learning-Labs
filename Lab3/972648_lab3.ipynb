# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn.linear_model as sklm
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA

# %% [markdown]
# # Task 3.1

# %%
xdata = np.load("x_values-1.npy")
ydata = np.load("y_values-1.npy")

reg = sklm.LinearRegression().fit(xdata, ydata)

xtest = np.load("test_x_values-1.npy")
yout = reg.predict(xtest)

plt.ion()
plt.scatter(xdata, ydata)
plt.plot(xtest, yout)

test_scalar = np.array(0.48)
y_arr = test_scalar.reshape(1,-1)
y48 = reg.predict(y_arr)
print(y48)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/p4/8n8v7wmx1xj6g2fc157hrjzw0000gn/T/ipykernel_16687/2256366274.py in <module>
#       2 ydata = np.load("y_values-1.npy")
#       3
# ----> 4 reg = sk.linear_model.LinearRegression().fit(xdata, ydata)
#       5
#       6 xtest = np.load("test_x_values-1.npy")
#
# AttributeError: module 'sklearn.linear_model' has no attribute 'linear_model'

# %% [markdown]
# # Task 3.2

# %%
wine_data = np.load("wineData-1.npy")
wine_labels = np.load("wineLabels-1.npy")

print(wine_data.shape)

train_data, test_data, train_labels, test_labels = train_test_split(wine_data, wine_labels, test_size=0.2)

plt.scatter(train_data[:,0], train_data[:,1], c = train_labels)
plt.scatter(test_data[:,0], test_data[:,1], c = test_labels, marker='x')
# Out:
# (178, 13)

# %%
pca_train = PCA(n_components=2).fit_transform(train_data)
pca_test = PCA(n_components=2).fit_transform(test_data)

plt.scatter(pca_train[:,0], pca_train[:,1], c = train_labels)
plt.scatter(pca_test[:,0], pca_test[:,1], c = test_labels, marker=x)
